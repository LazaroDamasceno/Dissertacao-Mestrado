# %%
import geopandas as gpd
from matplotlib import pyplot as plt, gridspec

# %%
df = gpd.read_file('BR_UF_2024')

# %%
df
# Out:
#    CD_UF                NM_UF SIGLA_UF CD_REGIA      NM_REGIA SIGLA_RG  \
# 0     35            São Paulo       SP        3       Sudeste       SE
# 1     15                 Pará       PA        1         Norte        N
# 2     32       Espírito Santo       ES        3       Sudeste       SE
# 3     12                 Acre       AC        1         Norte        N
# 4     13             Amazonas       AM        1         Norte        N
# 5     33       Rio de Janeiro       RJ        3       Sudeste       SE
# 6     11             Rondônia       RO        1         Norte        N
# 7     31         Minas Gerais       MG        3       Sudeste       SE
# 8     52                Goiás       GO        5  Centro-oeste       CO
# 9     53     Distrito Federal       DF        5  Centro-oeste       CO
# 10    50   Mato Grosso do Sul       MS        5  Centro-oeste       CO
# 11    51          Mato Grosso       MT        5  Centro-oeste       CO
# ...

# %%
df.loc[df['NM_REGIA'].isin(['Sudeste']), 'SC1'] = 12
df.loc[df['NM_REGIA'].isin(['Nordeste']), 'SC1'] = 5
df.loc[df['NM_REGIA'].isin(['Sul']), 'SC1'] = 13
df.loc[df['NM_REGIA'].isin(['Norte']), 'SC1'] = 7
df.loc[df['NM_REGIA'].isin(['Centro-oeste']), 'SC1'] = 7

# %%
df.loc[df['NM_REGIA'].isin(['Sudeste']), 'SC2'] = 12
df.loc[df['NM_REGIA'].isin(['Nordeste']), 'SC2'] = 6
df.loc[df['NM_REGIA'].isin(['Sul']), 'SC2'] = 9
df.loc[df['NM_REGIA'].isin(['Norte']), 'SC2'] = 9
df.loc[df['NM_REGIA'].isin(['Centro-oeste']), 'SC2'] = 10

# %%
df.loc[df['NM_REGIA'].isin(['Sudeste']), 'SC3'] = 12
df.loc[df['NM_REGIA'].isin(['Nordeste']), 'SC3'] = 12
df.loc[df['NM_REGIA'].isin(['Sul']), 'SC3'] = 10
df.loc[df['NM_REGIA'].isin(['Norte']), 'SC3'] = 13
df.loc[df['NM_REGIA'].isin(['Centro-oeste']), 'SC3'] = 5

# %%
df
# Out:
#    CD_UF                NM_UF SIGLA_UF CD_REGIA      NM_REGIA SIGLA_RG  \
# 0     35            São Paulo       SP        3       Sudeste       SE
# 1     15                 Pará       PA        1         Norte        N
# 2     32       Espírito Santo       ES        3       Sudeste       SE
# 3     12                 Acre       AC        1         Norte        N
# 4     13             Amazonas       AM        1         Norte        N
# 5     33       Rio de Janeiro       RJ        3       Sudeste       SE
# 6     11             Rondônia       RO        1         Norte        N
# 7     31         Minas Gerais       MG        3       Sudeste       SE
# 8     52                Goiás       GO        5  Centro-oeste       CO
# 9     53     Distrito Federal       DF        5  Centro-oeste       CO
# 10    50   Mato Grosso do Sul       MS        5  Centro-oeste       CO
# 11    51          Mato Grosso       MT        5  Centro-oeste       CO
# ...

# %%
fig = plt.figure(figsize=(10, 10))
gs = gridspec.GridSpec(nrows=2, ncols=2, figure=fig)

sc1_ax = fig.add_subplot(gs[0, 0])
sc1_plot = df.plot(
    column='SC1',
    legend=True,
    ax=sc1_ax,
    legend_kwds={
        'orientation': 'horizontal'
    }
)
sc1_plot.axis('off')
sc1_plot.set_title('SC1')

sc2_ax = fig.add_subplot(gs[0, 1])
sc2_plot = df.plot(
    column='SC2',
    legend=True,
    ax=sc2_ax,
        legend_kwds={
        'orientation': 'horizontal'
    }
)
sc2_plot.axis('off')
sc2_plot.set_title('SC2')

sc3_ax = fig.add_subplot(gs[1, :])
sc3_plot = df.plot(
    column='SC3',
    legend=True,
    ax=sc3_ax
)
sc3_plot.axis('off')
sc3_plot.set_title('SC3')

plt.tight_layout()
plt.savefig('C:/Users/lazar/Master-Dissertation/figuras/mapa_coropletico_tic_domicilios_2024_g2a_1.png', dpi=300, bbox_inches='tight')
plt.show()
