# %%
import geopandas as gpd

# %%
geo_dados = gpd.read_file('BR_UF_2024')

# %%
geo_dados.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CD_UF     27 non-null     object
#  1   NM_UF     27 non-null     object
#  2   SIGLA_UF  27 non-null     object
#  3   CD_REGIA  27 non-null     object
#  4   NM_REGIA  27 non-null     object
#  5   SIGLA_RG  27 non-null     object
#  6   AREA_KM2  27 non-null     float64
#  7   geometry  27 non-null     geometry
# dtypes: float64(1), geometry(1), object(6)
# memory usage: 1.8+ KB

# %%
geo_dados.loc[geo_dados['NM_REGIA'].isin(['Sudeste']), 'Valor'] = 65
geo_dados.loc[geo_dados['NM_REGIA'].isin(['Nordeste']), 'Valor'] = 49
geo_dados.loc[geo_dados['NM_REGIA'].isin(['Sul']), 'Valor'] = 72
geo_dados.loc[geo_dados['NM_REGIA'].isin(['Norte']), 'Valor'] = 60
geo_dados.loc[geo_dados['NM_REGIA'].isin(['Centro-oeste']), 'Valor'] = 56

# %%
geo_dados
# Out:
#    CD_UF                NM_UF SIGLA_UF CD_REGIA      NM_REGIA SIGLA_RG  \
# 0     35            São Paulo       SP        3       Sudeste       SE
# 1     15                 Pará       PA        1         Norte        N
# 2     32       Espírito Santo       ES        3       Sudeste       SE
# 3     12                 Acre       AC        1         Norte        N
# 4     13             Amazonas       AM        1         Norte        N
# 5     33       Rio de Janeiro       RJ        3       Sudeste       SE
# 6     11             Rondônia       RO        1         Norte        N
# 7     31         Minas Gerais       MG        3       Sudeste       SE
# 8     52                Goiás       GO        5  Centro-oeste       CO
# 9     53     Distrito Federal       DF        5  Centro-oeste       CO
# 10    50   Mato Grosso do Sul       MS        5  Centro-oeste       CO
# 11    51          Mato Grosso       MT        5  Centro-oeste       CO
# ...

# %%
ax = geo_dados.plot(
    column='Valor',
    legend=True,
    cmap='Dark2',
    figsize=(12, 8)
)

ax.axis('off')

fig = ax.get_figure()
fig.tight_layout()
fig.savefig('C:/Users/lazar/Master-Dissertation/figuras/mapa_coropletico_tic_domicilios_2024_g1.png', dpi=300, bbox_inches='tight')
fig.show()
# Out:
# C:\Users\lazar\AppData\Local\Temp\ipykernel_5920\1019546836.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
