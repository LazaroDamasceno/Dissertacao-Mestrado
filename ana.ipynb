# %%
import pandas as pd
from itertools import chain

# %%
df = pd.read_csv('UN_EGDI_EGDI_WIDEF.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   FREQ                193 non-null    object
#  1   FREQ_LABEL          193 non-null    object
#  2   REF_AREA            193 non-null    object
#  3   REF_AREA_LABEL      193 non-null    object
#  4   INDICATOR           193 non-null    object
#  5   INDICATOR_LABEL     193 non-null    object
#  6   UNIT_MEASURE        193 non-null    object
#  7   UNIT_MEASURE_LABEL  193 non-null    object
#  8   DATABASE_ID         193 non-null    object
#  9   DATABASE_ID_LABEL   193 non-null    object
#  10  UNIT_MULT           193 non-null    int64
#  11  UNIT_MULT_LABEL     193 non-null    object
#  12  OBS_STATUS          193 non-null    object
#  13  OBS_STATUS_LABEL    193 non-null    object
#  14  OBS_CONF            193 non-null    object
# ...

# %%
df = df.iloc[:, chain([3], range(16, 28))]

# %%
df
# Out:
#            REF_AREA_LABEL     2003     2004     2005    2008     2010  \
# 0             Afghanistan  0.11752  0.13367  0.14898  0.2048  0.20976
# 1                  Angola  0.19222  0.19980  0.18400  0.3328  0.31098
# 2                 Albania  0.31079  0.33998  0.37316  0.4670  0.45192
# 3                 Andorra  0.17416  0.15633  0.18363  0.5175  0.51478
# 4    United Arab Emirates  0.53450  0.47356  0.57182  0.6301  0.53494
# ..                    ...      ...      ...      ...     ...      ...
# 188                 Samoa  0.29927  0.37926  0.39769  0.3761  0.37419
# 189           Yemen, Rep.  0.18758  0.19483  0.21249  0.2142  0.21541
# 190          South Africa  0.51503  0.49021  0.50754  0.5115  0.43057
# 191                Zambia  0.27644  0.00000  0.00000  0.2266  0.28098
# 192              Zimbabwe  0.30438  0.28330  0.33161  0.3000  0.32304
#
#         2012     2014     2016    2018    2020    2022     2024
# ...
