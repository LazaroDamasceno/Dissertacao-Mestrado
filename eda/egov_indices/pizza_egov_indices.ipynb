# %%
import pandas as pd

# %%
df = 
    'EGDI': 16_800,
    'DGI': 563,
    'GTMI': 418
}

# %%
df = pd.DataFrame(data, [0])

# %%
df = df.melt(
    value_vars=['EGDI', 'DGI', 'GTMI'],
    var_name='Metricas',
    value_name='Quantidade'
)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.pie(df['Quantidade'], labels=df['Metricas'], colors=plt.cm.Set1.colors)

plt.tight_layout()
plt.savefig('C:/Users/lazar/Master-Dissertation/figuras/indices/indices_google_academico.png', dpi=300, bbox_inches='tight')
plt.show()
