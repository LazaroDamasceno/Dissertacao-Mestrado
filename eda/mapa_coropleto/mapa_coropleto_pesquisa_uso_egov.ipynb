# %%
import pandas as pd
import geopandas
import matplotlib.pyplot as plt

# %%
gdf = geopandas.read_file('brazil_geo.json')

# %%
uso_egov_regioes = {
    'Sudeste': 65.0,
    'Nordeste': 49.0,
    'Sul': 72.0, 
    'Norte': 60.0, 
    'Centro-Oeste': 56.0
}

# %%
gdf['uso_egov'] = [
    uso_egov_regioes['Norte'],
    uso_egov_regioes['Norte'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Norte'],
    uso_egov_regioes['Norte'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Centro-Oeste'],
    uso_egov_regioes['Sudeste'],
    uso_egov_regioes['Centro-Oeste'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Centro-Oeste'],
    uso_egov_regioes['Centro-Oeste'],
    uso_egov_regioes['Sudeste'],
    uso_egov_regioes['Norte'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Sul'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Sudeste'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Sul'],
    uso_egov_regioes['Norte'],
    uso_egov_regioes['Norte'],
    uso_egov_regioes['Sul'],
    uso_egov_regioes['Sudeste'],
    uso_egov_regioes['Nordeste'],
    uso_egov_regioes['Norte']
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 gdf['uso_egov'] = [
#       2     uso_egov_regioes['Norte'],
#       3     uso_egov_regioes['Norte'],
#       4     uso_egov_regioes['Nordeste'],
#       5     uso_egov_regioes['Norte'],
#       6     uso_egov_regioes['Norte'],
#       7     uso_egov_regioes['Nordeste'],
#       8     uso_egov_regioes['Nordeste'],
#       9     uso_egov_regioes['Centro-Oeste'],
#      10     uso_egov_regioes['Sudeste'],
#      11     uso_egov_regioes['Centro-Oeste'],
#      12     uso_egov_regioes['Nordeste'],
#      13     uso_egov_regioes['Centro-Oeste'],
#      14     uso_egov_regioes['Centro-Oeste'],
#      15     uso_egov_regioes['Sudeste'],
#      16     uso_egov_regioes['Norte'],
#      17     uso_egov_regioes['Nordeste'],
#      18     uso_egov_regioes['Sul'],
#      19     uso_egov_regioes['Nordeste'],
# ...

# %%
gdf.plot(column='uso_egov',
        cmap='viridis',
        legend=True,
        legend_kwds={
            'orientation': "horizontal"
        },
        figsize=(10, 6)
)

plt.savefig('C:/Users/lazar/Master-Dissertation/figuras/mapa_coropleto_paises_uso_egov_regioes.png', dpi=300, bbox_inches='tight')
plt.show()
