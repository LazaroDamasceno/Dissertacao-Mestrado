# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
egdi_brazil = pd.read_csv('concated_egdi_brazil.csv')
egdi_russia = pd.read_csv('concated_egdi_russia.csv')

# %%
edi_brazil = pd.read_csv('electoral_democracy_index_brazil.csv')
edi_russia = pd.read_csv('electoral_democracy_index_russia.csv')

# %%
df = pd.DataFrame()
df['EGDI do Brasil'] = egdi_brazil['Percentage']
df['EGDI da Russia'] = egdi_russia['Percentage']
df['IDE do Brasil'] = edi_brazil['Index']
df['IDE do Russia'] = edi_russia['Index']

# %%
corr = df.corr(method='pearson')

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.heatmap(data=corr, annot=True)

plt.suptitle('IDE = Índice de Democracia Eleitoral')
plt.tight_layout()
plt.show()
fig.savefig('C:/Users/lazar/Master-Dissertation/figuras/egdi/correlacao3.png')
